# %% [markdown]
# <a href="https://colab.research.google.com/github/syarifahkemala/Bootcamp-Sanbercode/blob/main/Tugas_Hari_2_Pekan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
import matplotlib.pyplot as plt
plt.figure(figsize=(10,12))

fig, ax = plt.subplots()
ax.plot(x, cos, color='red')
ax.plot(x, cos3,linestyle='--', color='green')
ax.plot(x, sin, linestyle='dashdot', color='blue')
ax.plot(x, sin2, linestyle='none', marker='x',color='yellow')

ax.set_xlabel('X-Axis Label')
ax.set_ylabel('Y-Axis Label')
ax.set_title('Grafik Cos Sin')

plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
